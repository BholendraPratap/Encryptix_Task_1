# %% [markdown]
# ### Data loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("fraudTrain.csv")

# %%
dft=pd.read_csv("fraudTest.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
dft.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
dft.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
dft.drop(columns=['Unnamed: 0'],inplace=True)

# %%
dft.columns
# Out:
# Index(['trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute',
#        'age', 'merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      lat      long  \
# 0                561 Perry Cove  Moravian Falls  ...  36.0788  -81.1781
# ...

# %%
dft.head()
# Out:
#   trans_date_trans_time            cc_num  \
# 0   2020-06-21 12:14:25  2291163933867244
# 1   2020-06-21 12:14:33  3573030041201292
# 2   2020-06-21 12:14:53  3598215285024754
# 3   2020-06-21 12:15:15  3591919803438423
# 4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city  ...      lat  \
# 0   Elliott      M            351 Darlene Green    Columbia  ...  33.9659
# 1  Williams      F             3638 Marsh Union     Altonah  ...  40.3207
# ...

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.drop(columns=['cc_num','street','first','last'],inplace=True)

# %%
dft.drop(columns=['cc_num','street','first','last'],inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2   2019-01-01 00:00:51                fraud_Lind-Buckridge  entertainment
# 3   2019-01-01 00:01:16  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   2019-01-01 00:03:06                 fraud_Keeling-Crist       misc_pos
#
#       amt gender            city state    zip      lat      long  city_pop  \
# 0    4.97      F  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1  107.23      F          Orient    WA  99160  48.8878 -118.2105       149
# 2  220.11      M      Malad City    ID  83252  42.1808 -112.2620      4154
# 3   45.00      M         Boulder    MT  59632  46.2306 -112.1138      1939
# 4   41.96      M        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#                                  job         dob  \
# ...

# %%
dft.head()
# Out:
#   trans_date_trans_time                              merchant        category  \
# 0   2020-06-21 12:14:25                 fraud_Kirlin and Sons   personal_care
# 1   2020-06-21 12:14:33                  fraud_Sporer-Keebler   personal_care
# 2   2020-06-21 12:14:53  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3   2020-06-21 12:15:15                     fraud_Haley Group        misc_pos
# 4   2020-06-21 12:15:17                 fraud_Johnston-Casper          travel
#
#      amt gender        city state    zip      lat      long  city_pop  \
# 0   2.86      M    Columbia    SC  29209  33.9659  -80.9355    333497
# 1  29.84      F     Altonah    UT  84002  40.3207 -110.4360       302
# 2  41.28      F    Bellmore    NY  11710  40.6729  -73.5365     34496
# 3  60.05      M  Titusville    FL  32780  28.5697  -80.8191     54767
# 4   3.19      M    Falmouth    MI  49632  44.2529  -85.0170      1126
#
#                       job         dob                         trans_num  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  object
#  1   merchant               1296675 non-null  object
#  2   category               1296675 non-null  object
#  3   amt                    1296675 non-null  float64
#  4   gender                 1296675 non-null  object
#  5   city                   1296675 non-null  object
#  6   state                  1296675 non-null  object
#  7   zip                    1296675 non-null  int64
#  8   lat                    1296675 non-null  float64
#  9   long                   1296675 non-null  float64
#  10  city_pop               1296675 non-null  int64
#  11  job                    1296675 non-null  object
#  12  dob                    1296675 non-null  object
#  13  trans_num              1296675 non-null  object
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  555719 non-null  object
#  1   merchant               555719 non-null  object
#  2   category               555719 non-null  object
#  3   amt                    555719 non-null  float64
#  4   gender                 555719 non-null  object
#  5   city                   555719 non-null  object
#  6   state                  555719 non-null  object
#  7   zip                    555719 non-null  int64
#  8   lat                    555719 non-null  float64
#  9   long                   555719 non-null  float64
#  10  city_pop               555719 non-null  int64
#  11  job                    555719 non-null  object
#  12  dob                    555719 non-null  object
#  13  trans_num              555719 non-null  object
# ...

# %%
###now checking for null or missing values in our data:
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# merchant                 0
# category                 0
# amt                      0
# gender                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
dft.isnull().sum()
# Out:
# trans_date_trans_time    0
# merchant                 0
# category                 0
# amt                      0
# gender                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# #### Hence there is no any null value

# %%
### now we will extract day ,month,hour,minute from tansaction date and time it will be benficial to track fraudlent transactions:
df['trans_date_trans_time']=pd.to_datetime(df['trans_date_trans_time'])
df['trans_day']=df['trans_date_trans_time'].dt.day
df['trans_month']=df['trans_date_trans_time'].dt.month
df['trans_year']=df['trans_date_trans_time'].dt.year
df['trans_hour']=df['trans_date_trans_time'].dt.hour
df['trans_minute']=df['trans_date_trans_time'].dt.minute

# %%
dft['trans_date_trans_time']=pd.to_datetime(dft['trans_date_trans_time'])
dft['trans_day']=dft['trans_date_trans_time'].dt.day
dft['trans_month']=dft['trans_date_trans_time'].dt.month
dft['trans_year']=dft['trans_date_trans_time'].dt.year
dft['trans_hour']=dft['trans_date_trans_time'].dt.hour
dft['trans_minute']=dft['trans_date_trans_time'].dt.minute

# %%
df.head()
# Out:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2   2019-01-01 00:00:51                fraud_Lind-Buckridge  entertainment
# 3   2019-01-01 00:01:16  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   2019-01-01 00:03:06                 fraud_Keeling-Crist       misc_pos
#
#       amt gender            city state    zip      lat      long  ...  \
# 0    4.97      F  Moravian Falls    NC  28654  36.0788  -81.1781  ...
# 1  107.23      F          Orient    WA  99160  48.8878 -118.2105  ...
# 2  220.11      M      Malad City    ID  83252  42.1808 -112.2620  ...
# 3   45.00      M         Boulder    MT  59632  46.2306 -112.1138  ...
# 4   41.96      M        Doe Hill    VA  24433  38.4207  -79.4629  ...
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# ...

# %%
dft.head()
# Out:
#   trans_date_trans_time                              merchant        category  \
# 0   2020-06-21 12:14:25                 fraud_Kirlin and Sons   personal_care
# 1   2020-06-21 12:14:33                  fraud_Sporer-Keebler   personal_care
# 2   2020-06-21 12:14:53  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3   2020-06-21 12:15:15                     fraud_Haley Group        misc_pos
# 4   2020-06-21 12:15:17                 fraud_Johnston-Casper          travel
#
#      amt gender        city state    zip      lat      long  ...  \
# 0   2.86      M    Columbia    SC  29209  33.9659  -80.9355  ...
# 1  29.84      F     Altonah    UT  84002  40.3207 -110.4360  ...
# 2  41.28      F    Bellmore    NY  11710  40.6729  -73.5365  ...
# 3  60.05      M  Titusville    FL  32780  28.5697  -80.8191  ...
# 4   3.19      M    Falmouth    MI  49632  44.2529  -85.0170  ...
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# ...

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'trans_num', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud',
#        'trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute'],
#       dtype='object')

# %%
df['dob']
# Out:
# 0          1988-03-09
# 1          1978-06-21
# 2          1962-01-19
# 3          1967-01-12
# 4          1986-03-28
#               ...
# 1296670    1961-11-24
# 1296671    1979-12-11
# 1296672    1967-08-30
# 1296673    1980-08-18
# 1296674    1995-08-16
# Name: dob, Length: 1296675, dtype: object

# %%
###now calculating age of customer :
df['dob'] = pd.to_datetime(df['dob'])
df['age'] = (df['trans_date_trans_time'] - df['dob']).dt.days // 365
df.drop(columns=['dob'], inplace=True)

# %%
###now calculating age of customer :
dft['dob'] = pd.to_datetime(dft['dob'])
dft['age'] = (dft['trans_date_trans_time'] - dft['dob']).dt.days // 365
dft.drop(columns=['dob'], inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2   2019-01-01 00:00:51                fraud_Lind-Buckridge  entertainment
# 3   2019-01-01 00:01:16  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   2019-01-01 00:03:06                 fraud_Keeling-Crist       misc_pos
#
#       amt gender            city state    zip      lat      long  ...  \
# 0    4.97      F  Moravian Falls    NC  28654  36.0788  -81.1781  ...
# 1  107.23      F          Orient    WA  99160  48.8878 -118.2105  ...
# 2  220.11      M      Malad City    ID  83252  42.1808 -112.2620  ...
# 3   45.00      M         Boulder    MT  59632  46.2306 -112.1138  ...
# 4   41.96      M        Doe Hill    VA  24433  38.4207  -79.4629  ...
#
#     unix_time  merch_lat  merch_long  is_fraud  trans_day  trans_month  \
# ...

# %%
dft.head()
# Out:
#   trans_date_trans_time                              merchant        category  \
# 0   2020-06-21 12:14:25                 fraud_Kirlin and Sons   personal_care
# 1   2020-06-21 12:14:33                  fraud_Sporer-Keebler   personal_care
# 2   2020-06-21 12:14:53  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3   2020-06-21 12:15:15                     fraud_Haley Group        misc_pos
# 4   2020-06-21 12:15:17                 fraud_Johnston-Casper          travel
#
#      amt gender        city state    zip      lat      long  ...   unix_time  \
# 0   2.86      M    Columbia    SC  29209  33.9659  -80.9355  ...  1371816865
# 1  29.84      F     Altonah    UT  84002  40.3207 -110.4360  ...  1371816873
# 2  41.28      F    Bellmore    NY  11710  40.6729  -73.5365  ...  1371816893
# 3  60.05      M  Titusville    FL  32780  28.5697  -80.8191  ...  1371816915
# 4   3.19      M    Falmouth    MI  49632  44.2529  -85.0170  ...  1371816917
#
# ...

# %%
df.drop(columns=['trans_date_trans_time'], inplace=True)

# %%
dft.drop(columns=['trans_date_trans_time'], inplace=True)

# %%
df.head()
# Out:
#                              merchant       category     amt gender  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97      F
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F
# 2                fraud_Lind-Buckridge  entertainment  220.11      M
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00      M
# 4                 fraud_Keeling-Crist       misc_pos   41.96      M
#
#              city state    zip      lat      long  city_pop  ...   unix_time  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781      3495  ...  1325376018
# 1          Orient    WA  99160  48.8878 -118.2105       149  ...  1325376044
# 2      Malad City    ID  83252  42.1808 -112.2620      4154  ...  1325376051
# 3         Boulder    MT  59632  46.2306 -112.1138      1939  ...  1325376076
# 4        Doe Hill    VA  24433  38.4207  -79.4629        99  ...  1325376186
#
#    merch_lat  merch_long  is_fraud  trans_day  trans_month  trans_year  \
# ...

# %%
dft.head()
# Out:
#                                merchant        category    amt gender  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86      M
# 1                  fraud_Sporer-Keebler   personal_care  29.84      F
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28      F
# 3                     fraud_Haley Group        misc_pos  60.05      M
# 4                 fraud_Johnston-Casper          travel   3.19      M
#
#          city state    zip      lat      long  city_pop  ...   unix_time  \
# 0    Columbia    SC  29209  33.9659  -80.9355    333497  ...  1371816865
# 1     Altonah    UT  84002  40.3207 -110.4360       302  ...  1371816873
# 2    Bellmore    NY  11710  40.6729  -73.5365     34496  ...  1371816893
# 3  Titusville    FL  32780  28.5697  -80.8191     54767  ...  1371816915
# 4    Falmouth    MI  49632  44.2529  -85.0170      1126  ...  1371816917
#
#    merch_lat  merch_long  is_fraud  trans_day  trans_month  trans_year  \
# ...

# %%
df.columns
# Out:
# Index(['merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'trans_day', 'trans_month', 'trans_year',
#        'trans_hour', 'trans_minute', 'age'],
#       dtype='object')

# %%
dft.columns
# Out:
# Index(['merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'trans_day', 'trans_month', 'trans_year',
#        'trans_hour', 'trans_minute', 'age'],
#       dtype='object')

# %%
df=df.reindex(columns=['trans_day', 'trans_month', 'trans_year',
       'trans_hour', 'trans_minute', 'age','merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip', 'lat',
       'long', 'city_pop', 'job', 'trans_num', 'unix_time', 'merch_lat',
       'merch_long', 'is_fraud'])

# %%
dft=dft.reindex(columns=['trans_day', 'trans_month', 'trans_year',
       'trans_hour', 'trans_minute', 'age','merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip', 'lat',
       'long', 'city_pop', 'job', 'trans_num', 'unix_time', 'merch_lat',
       'merch_long', 'is_fraud'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 22 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   trans_day     1296675 non-null  int32
#  1   trans_month   1296675 non-null  int32
#  2   trans_year    1296675 non-null  int32
#  3   trans_hour    1296675 non-null  int32
#  4   trans_minute  1296675 non-null  int32
#  5   age           1296675 non-null  int64
#  6   merchant      1296675 non-null  object
#  7   category      1296675 non-null  object
#  8   amt           1296675 non-null  float64
#  9   gender        1296675 non-null  object
#  10  city          1296675 non-null  object
#  11  state         1296675 non-null  object
#  12  zip           1296675 non-null  int64
#  13  lat           1296675 non-null  float64
#  14  long          1296675 non-null  float64
#  15  city_pop      1296675 non-null  int64
#  16  job           1296675 non-null  object
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   trans_day     555719 non-null  int32
#  1   trans_month   555719 non-null  int32
#  2   trans_year    555719 non-null  int32
#  3   trans_hour    555719 non-null  int32
#  4   trans_minute  555719 non-null  int32
#  5   age           555719 non-null  int64
#  6   merchant      555719 non-null  object
#  7   category      555719 non-null  object
#  8   amt           555719 non-null  float64
#  9   gender        555719 non-null  object
#  10  city          555719 non-null  object
#  11  state         555719 non-null  object
#  12  zip           555719 non-null  int64
#  13  lat           555719 non-null  float64
#  14  long          555719 non-null  float64
#  15  city_pop      555719 non-null  int64
#  16  job           555719 non-null  object
# ...

# %% [markdown]
# ### EDA:

# %%
#checking for fraud and non-fraud columns:
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
plt.pie(df['is_fraud'].value_counts(), labels=df['is_fraud'].value_counts().index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1916888e9f0>,
# ...
#  [Text(-1.0998181131964657, 0.02000294690705531, '0'),
#   Text(1.0998181149229591, -0.020002851979370503, '1')],
#  [Text(-0.5999007890162539, 0.010910698312939258, '99.4%'),
#   Text(0.5999007899579777, -0.010910646534202092, '0.6%')])

# %% [markdown]
# It is also imbalanced
#
# In this case, I want to balances uneven datasets with upsampling technique,
# by increasing the size of the data in the minority class to match data in the majority class.

# %%
#displaying each category:
df['category'].value_counts()
# Out:
# category
# gas_transport     131659
# grocery_pos       123638
# home              123115
# shopping_pos      116672
# kids_pets         113035
# shopping_net       97543
# entertainment      94014
# food_dining        91461
# personal_care      90758
# health_fitness     85879
# misc_pos           79655
# misc_net           63287
# grocery_net        45452
# travel             40507
# Name: count, dtype: int64

# %%
dft['category'].value_counts()
# Out:
# category
# gas_transport     56370
# grocery_pos       52553
# home              52345
# shopping_pos      49791
# kids_pets         48692
# shopping_net      41779
# entertainment     40104
# personal_care     39327
# food_dining       39268
# health_fitness    36674
# misc_pos          34574
# misc_net          27367
# grocery_net       19426
# travel            17449
# Name: count, dtype: int64

# %%
plt.pie(df['category'].value_counts(), labels=df['category'].value_counts().index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19147a9a060>,
# ...
#  [Text(1.0445098845465166, 0.344962463297998, 'gas_transport'),
#   Text(0.6509682912284626, 0.8867019137314951, 'grocery_pos'),
#   Text(0.03897810205058762, 1.0993091956135608, 'home'),
#   Text(-0.5707446836773632, 0.9403459501981314, 'shopping_pos'),
#   Text(-0.9813494356082109, 0.4969439457639524, 'kids_pets'),
#   Text(-1.0990554288664822, -0.04557591775392924, 'shopping_net'),
#   Text(-0.9623990424341992, -0.5327176392064905, 'entertainment'),
#   Text(-0.6354413949185906, -0.8978943332173981, 'food_dining'),
#   Text(-0.1908634314885612, -1.0833148898267815, 'personal_care'),
#   Text(0.2759394582280168, -1.0648274110825795, 'health_fitness'),
#   Text(0.6697429860894591, -0.8726077770590718, 'misc_pos'),
#   Text(0.9261763929225474, -0.5934621211105048, 'misc_net'),
#   Text(1.0487672753419615, -0.3317939152121368, 'grocery_net'),
#   Text(1.0947068763388075, -0.10778151463275534, 'travel')],
# ...

# %%
###now evaluating the amount column :
df['amt'].describe()
# Out:
# count    1.296675e+06
# mean     7.035104e+01
# std      1.603160e+02
# min      1.000000e+00
# 25%      9.650000e+00
# 50%      4.752000e+01
# 75%      8.314000e+01
# max      2.894890e+04
# Name: amt, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['amt'], kde=True, color='blue', bins=50)
plt.title('Distribution of Transaction Amounts in the Training Data')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The transaction amounts in both train_data and test_data has a very left skewed distribution with a large number of small transactions and a few large ones.
#
# Large amounts could potentially be associated with fraudulent activity.

# %%
###checking which gender counts:
df['gender'].value_counts()
# Out:
# gender
# F    709863
# M    586812
# Name: count, dtype: int64

# %% [markdown]
# #### Preprocessing of data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 22 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   trans_day     1296675 non-null  int32
#  1   trans_month   1296675 non-null  int32
#  2   trans_year    1296675 non-null  int32
#  3   trans_hour    1296675 non-null  int32
#  4   trans_minute  1296675 non-null  int32
#  5   age           1296675 non-null  int64
#  6   merchant      1296675 non-null  object
#  7   category      1296675 non-null  object
#  8   amt           1296675 non-null  float64
#  9   gender        1296675 non-null  object
#  10  city          1296675 non-null  object
#  11  state         1296675 non-null  object
#  12  zip           1296675 non-null  int64
#  13  lat           1296675 non-null  float64
#  14  long          1296675 non-null  float64
#  15  city_pop      1296675 non-null  int64
#  16  job           1296675 non-null  object
# ...

# %%
# Select only numeric columns for correlation analysis
numeric_data = df.select_dtypes(include=[np.number])

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap (Numeric Columns Only)')
plt.show()

# %% [markdown]
# ###### We will drop the unix time columns which is highly correlated with the trans_year column which generates the multi collinearity in the dataset.

# %%
# Drop unnecessary columns (only include columns that exist in the dataset)
columns_to_drop = ['trans_num', 'unix_time']
df.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore') #train data
dft.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore') #test data

# %%
### regenerating the heat map:>
# Select only numeric columns for correlation analysis
numeric_data = df.select_dtypes(include=[np.number])

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap (Numeric Columns Only)')
plt.show()

# %%
## Again checking that no any unwanted columns should present:
print(df.columns)
print(dft.columns)
# Out:
# Index(['trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute',
#        'age', 'merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'merch_lat', 'merch_long',
#        'is_fraud'],
#       dtype='object')
# Index(['trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute',
#        'age', 'merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'merch_lat', 'merch_long',
#        'is_fraud'],
#       dtype='object')

# %% [markdown]
# ##### Feature engineering:

# %% [markdown]
# ##### Prepare the dataset for modeling by encoding categorical variables, scaling numerical features, and handling missing values.

# %%
# Define features (X) and target (y) for the training dataset
X_train = df.drop('is_fraud', axis=1)  # Features (all columns except 'is_fraud')
y_train = df['is_fraud']  # Target variable ('is_fraud')

# Define features (X) and target (y) for the testing dataset
X_test = dft.drop('is_fraud', axis=1)  # Features (all columns except 'is_fraud')
y_test = dft['is_fraud']  # Target variable ('is_fraud')

# Dynamically identify categorical and numerical columns
categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()
numerical_cols=X_train.select_dtypes(include=[np.number]).columns.tolist()

# %%
categorical_cols
# Out:
# ['merchant', 'category', 'gender', 'city', 'state', 'job']

# %%
numerical_cols
# Out:
# ['trans_day',
#  'trans_month',
#  'trans_year',
#  'trans_hour',
#  'trans_minute',
#  'age',
#  'amt',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'merch_lat',
#  'merch_long']

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
# Encode categorical variables using LabelEncoder
label_encoder = LabelEncoder()
for col in categorical_cols:
    # Fit LabelEncoder on the union of train and test data to avoid unseen labels
    combined = pd.concat([X_train[col], X_test[col]])
    label_encoder.fit(combined)

    # Transform both train and test data
    X_train[col] = label_encoder.transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

# %%
# Scale numerical features using StandardScaler
scaler = StandardScaler()
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])  # Use transform (not fit_transform) for test data

# %%
X_train.head()
# Out:
#    trans_day  trans_month  trans_year  trans_hour  trans_minute       age  \
# 0  -1.652258    -1.504564   -0.634065   -1.878145     -1.702944 -0.891968
# 1  -1.652258    -1.504564   -0.634065   -1.878145     -1.702944 -0.317551
# 2  -1.652258    -1.504564   -0.634065   -1.878145     -1.702944  0.601517
# 3  -1.652258    -1.504564   -0.634065   -1.878145     -1.645208  0.371750
# 4  -1.652258    -1.504564   -0.634065   -1.878145     -1.529736 -0.777085
#
#    merchant  category       amt  gender  city  state       zip       lat  \
# 0       514         8 -0.407826       0   532     27 -0.749136 -0.484420
# 1       241         4  0.230039       0   619     47  1.872567  2.039120
# 2       390         0  0.934149       1   474     13  1.281042  0.717754
# 3       360         2 -0.158132       1    84     26  0.402753  1.515617
# 4       297         9 -0.177094       1   217     45 -0.906090 -0.023035
#
#        long  city_pop  job  merch_lat  merch_long
# ...

# %%
X_test.head()
# Out:
#    trans_day  trans_month  trans_year  trans_hour  trans_minute       age  \
# 0   0.612974    -0.041592    1.577126   -0.118052     -0.894638  0.371750
# 1   0.612974    -0.041592    1.577126   -0.118052     -0.894638 -0.891968
# 2   0.612974    -0.041592    1.577126   -0.118052     -0.894638  0.199425
# 3   0.612974    -0.041592    1.577126   -0.118052     -0.836902 -0.777085
# 4   0.612974    -0.041592    1.577126   -0.118052     -0.836902  1.118492
#
#    merchant  category       amt  gender  city  state       zip       lat  \
# 0       319        10 -0.420988       1   168     40 -0.728499 -0.900689
# 1       591        10 -0.252695       0    16     44  1.308930  0.351290
# 2       611         5 -0.181336       0    64     34 -1.379183  0.420678
# 3       222         9 -0.064255       1   814      9 -0.595714 -1.963810
# 4       292        13 -0.418929       1   262     22  0.030912  1.125984
#
#        long  city_pop  job  merch_lat  merch_long
# ...

# %%
# Ensure X_train and X_test have the same columns
X_train, X_test = X_train.align(X_test, join='inner', axis=1)

# %%
# Print the final set of columns to verify
print("Final set of columns in X_train and X_test:")
print(X_train.columns)
print(X_test.columns)
# Out:
# Final set of columns in X_train and X_test:
# Index(['trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute',
#        'age', 'merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'merch_lat', 'merch_long'],
#       dtype='object')
# Index(['trans_day', 'trans_month', 'trans_year', 'trans_hour', 'trans_minute',
#        'age', 'merchant', 'category', 'amt', 'gender', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'merch_lat', 'merch_long'],
#       dtype='object')

# %% [markdown]
# #### Training the model:

# %% [markdown]
# ##### Firstly training model without balancing the dataset:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize the Random Forest Classifier with optimized parameters
model = RandomForestClassifier(
    n_estimators=100,       # Reduce the number of trees
    n_jobs=-1,             # Use all available CPU cores
    random_state=42
)

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# %% [markdown]
# #### Evalutaing the model:

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.96      0.69      0.81      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.98      0.85      0.90    555719
# weighted avg       1.00      1.00      1.00    555719
#
# Accuracy: 1.00

# %% [markdown]
# Its displaying 100% accuracy and its reflected that the model is performing for only one side not for both side and we have to need to balance the dataset.
# ##### Now balancing the dataset using SMOTE technique:

# %%
from imblearn.over_sampling import SMOTE

# %%
# Apply SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
y_resampled.value_counts()
# Out:
# is_fraud
# 0    1289169
# 1    1289169
# Name: count, dtype: int64

# %% [markdown]
# ######  now our data is balanced..

# %%
# Train the model on the resampled data
model.fit(X_resampled, y_resampled)

# Make predictions on the test data
y_pred_resampled = model.predict(X_test)

# Evaluate the model again
print("\nClassification Report After SMOTE:")
print(classification_report(y_test, y_pred_resampled))
# Out:
# Classification Report After SMOTE:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.59      0.63      0.61      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.80      0.82      0.80    555719
# weighted avg       1.00      1.00      1.00    555719

# %%
# Extract feature importance from the trained model
feature_importance = pd.DataFrame({
    'Feature': X_resampled.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False)

# Print feature importance
print("\nFeature Importance:")
print(feature_importance)

# Plot feature importance
plt.figure(figsize=(8, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title('Feature importance')
# Out:
# Feature Importance:
#          Feature  Importance
# 8            amt    0.562718
# 3     trans_hour    0.084629
# 2     trans_year    0.071251
# 7       category    0.065694
# 1    trans_month    0.030554
# 5            age    0.019792
# 15      city_pop    0.018275
# 0      trans_day    0.017408
# 12           zip    0.013864
# 10          city    0.013576
# 13           lat    0.013097
# 16           job    0.013029
# 4   trans_minute    0.012407
# 9         gender    0.011925
# 11         state    0.011548
# 14          long    0.010854
# 6       merchant    0.010269
# 18    merch_long    0.009603
# 17     merch_lat    0.009507
# Text(0.5, 1.0, 'Feature importance')

# %% [markdown]
# ##### hence we have get that the feature which are most important so we will choose them to again train the model because still our model accuracy after applying balancing technique is not good:

# %%
X_resampled
# Out:
#          trans_day  trans_month  trans_year  trans_hour  trans_minute  \
# 0        -1.652258    -1.504564   -0.634065   -1.878145     -1.702944
# 1        -1.652258    -1.504564   -0.634065   -1.878145     -1.702944
# 2        -1.652258    -1.504564   -0.634065   -1.878145     -1.702944
# 3        -1.652258    -1.504564   -0.634065   -1.878145     -1.645208
# 4        -1.652258    -1.504564   -0.634065   -1.878145     -1.529736
# ...            ...          ...         ...         ...           ...
# 2578333  -0.830942    -1.070520    1.577126   -0.303606     -0.531788
# 2578334   0.273189    -0.919375    1.577126    1.296082     -0.432153
# 2578335  -0.480483    -0.640012    0.712648   -1.820802     -1.190689
# 2578336  -1.317574     0.864780   -0.301543    0.988053     -0.983182
# 2578337  -1.404855    -0.015978    0.975936    0.590998     -1.272985
#
#               age  category       amt  gender  city  state       zip  \
# ...

# %%
y_resampled
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2578333    1
# 2578334    1
# 2578335    1
# 2578336    1
# 2578337    1
# Name: is_fraud, Length: 2578338, dtype: int64

# %%
#X_resampled.drop(columns=['merch_lat', 'merch_long', 'merchant', 'long'], inplace=True)
X_resampled.drop(columns=['lat'], inplace=True)

# %%
X_resampled.drop(columns=['state','zip','job','city','trans_day','trans_minute'], inplace=True)

# %%
###also dropping from the test dataset:
X_test
# Out:
#         trans_day  trans_month  trans_year  trans_hour  trans_minute  \
# 0        0.612974    -0.041592    1.577126   -0.118052     -0.894638
# 1        0.612974    -0.041592    1.577126   -0.118052     -0.894638
# 2        0.612974    -0.041592    1.577126   -0.118052     -0.894638
# 3        0.612974    -0.041592    1.577126   -0.118052     -0.836902
# 4        0.612974    -0.041592    1.577126   -0.118052     -0.836902
# ...           ...          ...         ...         ...           ...
# 555714   1.745590     1.713973    1.577126    1.495367      1.703488
# 555715   1.745590     1.713973    1.577126    1.495367      1.703488
# 555716   1.745590     1.713973    1.577126    1.495367      1.703488
# 555717   1.745590     1.713973    1.577126    1.495367      1.703488
# 555718   1.745590     1.713973    1.577126    1.495367      1.703488
#
#              age  merchant  category       amt  gender  city  state       zip  \
# ...

# %%
X_test.drop(columns=['state','zip','job','city','trans_day','trans_minute','merch_lat', 'merch_long', 'merchant', 'long'], inplace=True)

# %%
X_test.drop(columns=['lat'],inplace=True)

# %%
X_test
# Out:
#         trans_month  trans_year  trans_hour       age  category       amt  \
# 0         -0.041592    1.577126   -0.118052  0.371750        10 -0.420988
# 1         -0.041592    1.577126   -0.118052 -0.891968        10 -0.252695
# 2         -0.041592    1.577126   -0.118052  0.199425         5 -0.181336
# 3         -0.041592    1.577126   -0.118052 -0.777085         9 -0.064255
# 4         -0.041592    1.577126   -0.118052  1.118492        13 -0.418929
# ...             ...         ...         ...       ...       ...       ...
# 555714     1.713973    1.577126    1.495367  0.486633         5 -0.165804
# 555715     1.713973    1.577126    1.495367 -1.408944         7  0.258795
# 555716     1.713973    1.577126    1.495367 -0.374992         7  0.103102
# 555717     1.713973    1.577126    1.495367  0.544075        13 -0.388988
# 555718     1.713973    1.577126    1.495367 -1.064293         0 -0.200985
#
#         gender  city_pop
# 0            1  0.810291
# 1            0 -0.293163
# ...

# %%
X_resampled
# Out:
#          trans_month  trans_year  trans_hour       age  category       amt  \
# 0          -1.504564   -0.634065   -1.878145 -0.891968         8 -0.407826
# 1          -1.504564   -0.634065   -1.878145 -0.317551         4  0.230039
# 2          -1.504564   -0.634065   -1.878145  0.601517         0  0.934149
# 3          -1.504564   -0.634065   -1.878145  0.371750         2 -0.158132
# 4          -1.504564   -0.634065   -1.878145 -0.777085         9 -0.177094
# ...              ...         ...         ...       ...       ...       ...
# 2578333    -1.070520    1.577126   -0.303606  0.191812         7  3.126092
# 2578334    -0.919375    1.577126    1.296082  1.003609        10  3.523762
# 2578335    -0.640012    0.712648   -1.820802  0.765589         4  1.388001
# 2578336     0.864780   -0.301543    0.988053  0.552275         9  4.735466
# 2578337    -0.015978    0.975936    0.590998 -0.203199         9  3.053663
#
#          gender  city_pop
# 0             0 -0.282589
# ...

# %%
####again plotting correlation matrix, so we will combine both and X and y:
combined_resampled=pd.concat([X_resampled,y_resampled],axis=1)

# %%
combined_resampled.sample(10)
# Out:
#          trans_month  trans_year  trans_hour       age  category       amt  \
# 884267      1.713973   -0.634065    1.348692  0.256867         6 -0.110788
# 2508459     0.858152   -0.634065   -0.043472  0.346854         8  4.555712
# 2055688    -1.211969    0.264729    0.652253 -1.568665         9  5.452109
# 744148      1.421379   -0.634065    0.321971  0.371750         5 -0.240843
# 1140144    -0.626781    1.577126   -0.851424 -0.547318         4  0.190430
# 70255      -1.211969   -0.634065   -0.558075  0.716400         2 -0.037370
# 1842476    -1.211969   -0.634065   -0.526737 -0.087784         4 -0.380753
# 1114366    -0.626781    1.577126   -0.558075  2.152443        11 -0.405830
# 45252      -1.504564   -0.634065    1.348692 -0.719643        10 -0.122140
# 1628995     0.836191   -0.634065   -1.731471 -0.145226         6  3.655115
#
#          gender  city_pop  is_fraud
# 884267        1 -0.288679         0
# 2508459       1 -0.228352         1
# ...

# %%
combined_resampled.shape
# Out:
# (2578338, 9)

# %%
plt.figure(figsize=(12, 8))
corr_matrix = combined_resampled.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ##### now its clear and better .

# %% [markdown]
# #### agian training the models:

# %% [markdown]
# ##### Logistic regression:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix

# Train Logistic Regression
log_reg = LogisticRegression(max_iter=1000)
log_reg
# Out:
# LogisticRegression(max_iter=1000)

# %%
log_reg.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predict on test data
y_pred_log = log_reg.predict(X_test)
y_prob_log = log_reg.predict_proba(X_test)[:, 1]

# %%
roc_auc = roc_auc_score(y_test, y_prob_log)
print(f"ROC-AUC:   {roc_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_log))
# Out:
# ROC-AUC:   0.8576
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    553574
#            1       0.07      0.74      0.13      2145
#
#     accuracy                           0.96    555719
#    macro avg       0.53      0.85      0.55    555719
# weighted avg       1.00      0.96      0.98    555719

# %% [markdown]
# #### Decision tree classifier:

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42, max_depth=10, min_samples_split=10, min_samples_leaf=5)
dt.fit(X_resampled, y_resampled)

# Predict on test data
y_pred_dec = dt.predict(X_test)
y_prob_dec = dt.predict_proba(X_test)[:, 1]

# %%
fraud_indices = np.where(y_pred_dec == 1)[0]
fraud_indices
# Out:
# array([    33,    100,    167, ..., 555625, 555629, 555637], dtype=int64)

# %%
pd.Series(y_pred_dec).iloc[33]
# Out:
# 1

# %%
pd.Series(y_pred_dec).value_counts()
# Out:
# 0    544007
# 1     11712
# Name: count, dtype: int64

# %%
roc_auc_dec = roc_auc_score(y_test, y_prob_dec)
print(f"ROC-AUC:   {roc_auc_dec:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_log))
# Out:
# ROC-AUC:   0.9673
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    553574
#            1       0.07      0.74      0.13      2145
#
#     accuracy                           0.96    555719
#    macro avg       0.53      0.85      0.55    555719
# weighted avg       1.00      0.96      0.98    555719

# %% [markdown]
# #### Random forest classifier:

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_resampled, y_resampled)

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)
y_pred_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# %%
roc_auc_dec = roc_auc_score(y_test, y_pred_prob_rf)
print(f"ROC-AUC:   {roc_auc_dec:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# ROC-AUC:   0.9503
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.45      0.80      0.58      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.73      0.90      0.79    555719
# weighted avg       1.00      1.00      1.00    555719

# %% [markdown]
# #### here accuracy metrics is not enough to distinguish which is best that is why we use roc curve for better evalutaion of model.

# %% [markdown]
# ##### Final evaluation curve:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve

# Assuming you have trained multiple models (e.g., Logistic Regression, Decision Tree)
# You can store them in a dictionary for easy reference.
models = {
    "Logistic Regression": log_reg,  
    "Decision Tree": dt,              
    "Random Forest": rf_model,                         
}

# Create a figure for the ROC curves
plt.figure(figsize=(8, 6))

# Loop through each model and calculate its ROC-AUC score and plot the ROC curve
for model_name, model in models.items():
    # Get model predictions (probabilities for fraud, class 1)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    
    # Calculate ROC-AUC score
    roc_auc = roc_auc_score(y_test, y_pred_prob)
    
    # Calculate ROC curve (FPR, TPR)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    
    # Plot the ROC curve for each model
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot a diagonal line for random guessing
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label="Random Guessing (AUC = 0.5)")

# Add title and labels
plt.title('Receiver Operating Characteristic (ROC) Curve Comparison')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')

# Display legend
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ##### hence both decision tree and random forest have more near to 1 which is reflecting best performance of these models.

# %%
#done.
